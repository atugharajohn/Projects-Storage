# %%
#Anime Rating Case Study (What are the important factors influencing the rating of an anime
#and build a predictive model to predict the rating of the anime)

# %% [markdown]
# ## DATA PREPROCESSING

# %%
import numpy as np
import pandas as pd

#numpy is a library which used for working with arrays, it means numerical python

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %%
#'loading the dataset'

anime = pd.read_csv(r"C:\Users\User 1\Desktop\Ailead\anime.csv")

# %%
anime.head()
# Out:
#                                                title mediaType   eps  \
# 0                   Fullmetal Alchemist: Brotherhood        TV  64.0
# 1                                         your name.     Movie   1.0
# 2                                     A Silent Voice     Movie   1.0
# 3  Haikyuu!! Karasuno High School vs Shiratorizaw...        TV  10.0
# 4                Attack on Titan 3rd Season: Part II        TV  10.0
#
#    duration  ongoing  startYr  finishYr sznOfRelease  \
# 0       NaN    False   2009.0    2010.0       Spring
# 1     107.0    False   2016.0    2016.0          NaN
# 2     130.0    False   2016.0    2016.0          NaN
# 3       NaN    False   2016.0    2016.0         Fall
# 4       NaN    False   2019.0    2019.0       Spring
#
#                                          description               studios  \
# 0  The foundation of alchemy is based on the law ...             ['Bones']
# 1  Mitsuha and Taki are two total strangers livin...  ['CoMix Wave Films']
# ...

# %%
anime.tail(2)
# Out:
#                    title    mediaType  eps  duration  ongoing  startYr  \
# 14576         Kurayukaba        Movie  NaN       NaN    False      NaN
# 14577  YOASOBI: Harujion  Music Video  1.0       3.0    False   2020.0
#
#        finishYr sznOfRelease description      studios tags contentWarn  \
# 14576       NaN          NaN         NaN  ['Makaria']   []          []
# 14577    2020.0          NaN         NaN           []   []          []
#
#        watched  watching  wantWatch  dropped  rating  votes
# 14576      0.0         0         62        0     NaN    NaN
# 14577     13.0         0          6        2     NaN    NaN

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14578 entries, 0 to 14577
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         14578 non-null  object
#  1   mediaType     14510 non-null  object
#  2   eps           14219 non-null  float64
#  3   duration      9137 non-null   float64
#  4   ongoing       14578 non-null  bool
#  5   startYr       14356 non-null  float64
#  6   finishYr      14134 non-null  float64
#  7   sznOfRelease  3767 non-null   object
#  8   description   8173 non-null   object
#  9   studios       14578 non-null  object
#  10  tags          14578 non-null  object
#  11  contentWarn   14578 non-null  object
#  12  watched       14356 non-null  float64
#  13  watching      14578 non-null  int64
#  14  wantWatch     14578 non-null  int64
#  15  dropped       14578 non-null  int64
#  16  rating        12107 non-null  float64
#  17  votes         12119 non-null  float64
# ...

# %%
anime.isnull().sum()
# Out:
# title               0
# mediaType          68
# eps               359
# duration         5441
# ongoing             0
# startYr           222
# finishYr          444
# sznOfRelease    10811
# description      6405
# studios             0
# tags                0
# contentWarn         0
# watched           222
# watching            0
# wantWatch           0
# dropped             0
# rating           2471
# votes            2459
# dtype: int64

# %%
anime["duration"].unique()
# Out:
# array([ nan, 107., 130., 111., 125., 117.,  90., 118.,  83., 134.,  22.,
#         44., 105.,  86.,  47.,  45.,  24., 162., 112., 108.,  48.,  26.,
#         68., 104.,  98., 119., 116.,  95.,  49.,  27., 103.,  96.,  25.,
#        100., 114.,   4.,  23., 115., 148.,  88.,  60.,  34.,  62., 101.,
#         99.,  11.,  63.,  12., 110.,  20.,  50.,  28.,  15., 109., 120.,
#         40.,   6., 113.,  92.,  10., 102., 135.,   3.,  56., 121., 140.,
#         93., 150.,  16., 137.,  13.,   5.,  46.,  94., 163.,  14.,   7.,
#         71.,  89.,  51., 106.,  55., 127.,  18.,  58.,  91.,  19.,  52.,
#         80.,   8.,  87.,  78.,  75.,  84.,   2.,  65.,  30., 132.,  70.,
#         82.,  77.,  76.,  31.,  85.,  42.,  53.,  32.,  17.,  61.,  73.,
#         21.,   1.,  64.,  43.,  97.,  37., 123.,  69.,  38., 122.,  33.,
#         39.,   9., 136.,  72.,  57., 138., 141.,  29.,  54.,  35.,  66.,
#         74., 126.,  59., 152.,  79., 153.,  81., 131.,  36., 145.,  67.,
# ...

# %%
#check for duplicated date
anime.duplicated().sum()
# Out:
# 0

# %%
#CHECK COLUMN NAMES
anime.columns
# Out:
# Index(['title', 'mediaType', 'eps', 'duration', 'ongoing', 'startYr',
#        'finishYr', 'sznOfRelease', 'description', 'studios', 'tags',
#        'contentWarn', 'watched', 'watching', 'wantWatch', 'dropped', 'rating',
#        'votes'],
#       dtype='object')

# %%
#because I want predict rating, we have to drop the missing values in rating because we cannot predict nas
#how to drop
anime.dropna(subset = ["rating"], inplace = True)

# %%
#reset the dataframe index

anime.reset_index(drop = True, inplace = True)

# %%
#working on startyr
#lets check where its missing
anime[anime["startYr"].isnull()]
# Out:
#                                                    title    mediaType   eps  \
# 1405                             Unbelievable Space Love          Web  10.0
# 5222   Manbo-P: Irokoizata wa Subete Sakuzu de Kaiket...  Music Video   1.0
# 9813                        Mameshiba: Mamerry Christmas        Other   1.0
# 10258                                      Meow no Hoshi        Other   1.0
# 11970                                           Landmark          Web   1.0
# 12077                                      Burutabu-chan        Other   3.0
#
#        duration  ongoing  startYr  finishYr sznOfRelease description studios  \
# 1405        1.0    False      NaN       NaN          NaN         NaN      []
# 5222        5.0    False      NaN       NaN          NaN         NaN      []
# 9813        1.0    False      NaN       NaN          NaN         NaN      []
# 10258       5.0    False      NaN       NaN          NaN         NaN      []
# ...

# %%
#its a difficult column to clean as we dont know the start year so you need domain knowledge, so we just drop it
anime.dropna(subset = ["startYr"], inplace = True)

anime.reset_index(drop = True, inplace = True)

# %%
#finishyr column with null

anime[anime["finishYr"].isnull()]
# Out:
#                                                    title    mediaType     eps  \
# 13                             Kaguya-sama: Love Is War?           TV    10.0
# 46                                         Douluo Dalu 2          Web    82.0
# 70                              Fruits Basket 2nd Season           TV    10.0
# 111                    Ascendance of a Bookworm: Part II           TV    11.0
# 115                           Rakshasa Street 2nd Season          Web     5.0
# 121                                            Kingdom 3           TV     4.0
# 239                                            One Piece           TV   929.0
# 262                                         Tower of God           TV    11.0
# 314                                Wu Geng Ji 3rd Season          Web    21.0
# 324                       A Certain Scientific Railgun T           TV    15.0
# 350    My Next Life as a Villainess: All Routes Lead ...           TV    11.0
# ...

# %%
anime[anime["finishYr"].isnull()]

#all ongoing is True
# Out:
#                                                    title    mediaType     eps  \
# 13                             Kaguya-sama: Love Is War?           TV    10.0
# 46                                         Douluo Dalu 2          Web    82.0
# 70                              Fruits Basket 2nd Season           TV    10.0
# 111                    Ascendance of a Bookworm: Part II           TV    11.0
# 115                           Rakshasa Street 2nd Season          Web     5.0
# 121                                            Kingdom 3           TV     4.0
# 239                                            One Piece           TV   929.0
# 262                                         Tower of God           TV    11.0
# 314                                Wu Geng Ji 3rd Season          Web    21.0
# 324                       A Certain Scientific Railgun T           TV    15.0
# 350    My Next Life as a Villainess: All Routes Lead ...           TV    11.0
# ...

# %%
anime.describe(include = "all")
#since max of the finish yr is 2020 and the movies may still be on going, fill the missing values with year 2020
# Out:
#                                    title mediaType           eps     duration  \
# count                              12101     12038  12101.000000  7465.000000
# unique                             12101         8           NaN          NaN
# top     Fullmetal Alchemist: Brotherhood        TV           NaN          NaN
# freq                                   1      3993           NaN          NaN
# mean                                 NaN       NaN     13.393356    24.230141
# std                                  NaN       NaN     57.925097    31.468171
# min                                  NaN       NaN      1.000000     1.000000
# 25%                                  NaN       NaN      1.000000     4.000000
# 50%                                  NaN       NaN      2.000000     8.000000
# 75%                                  NaN       NaN     12.000000    30.000000
# max                                  NaN       NaN   2527.000000   163.000000
#
# ...

# %%
#fill the nan values in finishyr with 2020(set place to True)
anime.finishYr.fillna(2020, inplace = True)

# %%
anime.isnull().sum()
# Out:
# title              0
# mediaType         63
# eps                0
# duration        4636
# ongoing            0
# startYr            0
# finishYr           0
# sznOfRelease    8554
# description     4468
# studios            0
# tags               0
# contentWarn        0
# watched          115
# watching           0
# wantWatch          0
# dropped            0
# rating             0
# votes              0
# dtype: int64

# %%
#feature engineering
#creating a new column from another your dataset
#lets call the column "years_running" to know how long the movie ran for

# %%
#correct/convert data type of some of the columns 
anime["startYr"] = anime["startYr"].astype("int64")
anime["finishYr"] = anime["finishYr"].astype("int64")

# %%
anime["years_running"] = anime["finishYr"] - anime ["startYr"]

# %%
#we could drop the start year and finish year

# %%
anime.dtypes
# Out:
# title             object
# mediaType         object
# eps              float64
# duration         float64
# ongoing             bool
# startYr            int64
# finishYr           int64
# sznOfRelease      object
# description       object
# studios           object
# tags              object
# contentWarn       object
# watched          float64
# watching           int64
# wantWatch          int64
# dropped            int64
# rating           float64
# votes            float64
# years_running      int64
# dtype: object

# %%
anime.head()
# Out:
#                                                title mediaType   eps  \
# 0                   Fullmetal Alchemist: Brotherhood        TV  64.0
# 1                                         your name.     Movie   1.0
# 2                                     A Silent Voice     Movie   1.0
# 3  Haikyuu!! Karasuno High School vs Shiratorizaw...        TV  10.0
# 4                Attack on Titan 3rd Season: Part II        TV  10.0
#
#    duration  ongoing  startYr  finishYr sznOfRelease  \
# 0       NaN    False     2009      2010       Spring
# 1     107.0    False     2016      2016          NaN
# 2     130.0    False     2016      2016          NaN
# 3       NaN    False     2016      2016         Fall
# 4       NaN    False     2019      2019       Spring
#
#                                          description               studios  \
# 0  The foundation of alchemy is based on the law ...             ['Bones']
# 1  Mitsuha and Taki are two total strangers livin...  ['CoMix Wave Films']
# ...

# %%
#sznOfRelease: the seasons the movie was filled. It wont make sense to remove it. We can just fill it with "not known"
anime["sznOfRelease"].fillna("not_known", inplace = True)

# %%
anime["sznOfRelease"].value_counts()
# Out:
# is_missing    8554
# Spring        1135
# Fall          1011
# Winter         717
# Summer         684
# Name: sznOfRelease, dtype: int64

# %%
anime.head(2)
# Out:
#                               title mediaType   eps  duration  ongoing  \
# 0  Fullmetal Alchemist: Brotherhood        TV  64.0       NaN    False
# 1                        your name.     Movie   1.0     107.0    False
#
#    startYr  finishYr sznOfRelease  \
# 0     2009      2010       Spring
# 1     2016      2016   is_missing
#
#                                          description               studios  \
# 0  The foundation of alchemy is based on the law ...             ['Bones']
# 1  Mitsuha and Taki are two total strangers livin...  ['CoMix Wave Films']
#
#                                                 tags  \
# 0  ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...
# 1  ['Drama', 'Romance', 'Body Swapping', 'Gender ...
#
#                                          contentWarn   watched  watching  \
# 0  ['Animal Abuse', 'Mature Themes', 'Violence', ...  103707.0     14351
# 1                                                 []   58831.0      1453
#
# ...

# %%
#checking the value count for mediaType or unique values
anime["mediaType"].value_counts()
# Out:
# TV             3993
# Movie          1928
# OVA            1770
# Music Video    1290
# Web            1170
# DVD Special     803
# Other           580
# TV Special      504
# Name: mediaType, dtype: int64

# %%
#check missing values for mediatype
anime["mediaType"].isnull().sum()
# Out:
# 63

# %%
#we could as well just fill it with a value, lets say "not known"
anime["mediaType"].fillna("not_known", inplace = True)

# %%
anime.isnull().sum()
# Out:
# title               0
# mediaType           0
# eps                 0
# duration         4636
# ongoing             0
# startYr             0
# finishYr            0
# sznOfRelease        0
# description      4468
# studios             0
# tags                0
# contentWarn         0
# watched           115
# watching            0
# wantWatch           0
# dropped             0
# rating              0
# votes               0
# years_running       0
# dtype: int64

# %%
anime.head()
# Out:
#                                                title mediaType   eps  \
# 0                   Fullmetal Alchemist: Brotherhood        TV  64.0
# 1                                         your name.     Movie   1.0
# 2                                     A Silent Voice     Movie   1.0
# 3  Haikyuu!! Karasuno High School vs Shiratorizaw...        TV  10.0
# 4                Attack on Titan 3rd Season: Part II        TV  10.0
#
#    duration  ongoing  startYr  finishYr sznOfRelease  \
# 0       NaN    False     2009      2010       Spring
# 1     107.0    False     2016      2016   is_missing
# 2     130.0    False     2016      2016   is_missing
# 3       NaN    False     2016      2016         Fall
# 4       NaN    False     2019      2019       Spring
#
#                                          description               studios  \
# 0  The foundation of alchemy is based on the law ...             ['Bones']
# 1  Mitsuha and Taki are two total strangers livin...  ['CoMix Wave Films']
# ...

# %%
#remove the square brackets
anime["studios"] = anime["studios"].str.lstrip("[").str.rstrip("]")

# %%
anime["tags"] = anime["tags"].str.lstrip("[").str.rstrip("]")

# %%
anime["contentWarn"] = anime["contentWarn"].str.lstrip("[").str.rstrip("]")

# %%
anime["studios"] = anime["studios"].replace("", np.nan)

# %%
anime["tags"] = anime["tags"].replace("", np.nan)

# %%
anime["contentWarn"] = anime["contentWarn"].replace("", np.nan)

# %%
anime.head()
# Out:
#                                                title mediaType   eps  \
# 0                   Fullmetal Alchemist: Brotherhood        TV  64.0
# 1                                         your name.     Movie   1.0
# 2                                     A Silent Voice     Movie   1.0
# 3  Haikyuu!! Karasuno High School vs Shiratorizaw...        TV  10.0
# 4                Attack on Titan 3rd Season: Part II        TV  10.0
#
#    duration  ongoing  startYr  finishYr sznOfRelease  \
# 0       NaN    False     2009      2010       Spring
# 1     107.0    False     2016      2016   is_missing
# 2     130.0    False     2016      2016   is_missing
# 3       NaN    False     2016      2016         Fall
# 4       NaN    False     2019      2019       Spring
#
#                                          description             studios  \
# 0  The foundation of alchemy is based on the law ...             'Bones'
# 1  Mitsuha and Taki are two total strangers livin...  'CoMix Wave Films'
# ...

# %%
anime.isnull().sum()
# Out:
# title                0
# mediaType            0
# eps                  0
# duration          4636
# ongoing              0
# startYr              0
# finishYr             0
# sznOfRelease         0
# description       4468
# studios           3208
# tags               313
# contentWarn      10705
# watched            115
# watching             0
# wantWatch            0
# dropped              0
# rating               0
# votes                0
# years_running        0
# dtype: int64

# %%
#fill the duration with the mean of the column
anime["duration"].replace(np.nan, anime["duration"].mean(), inplace = True)

# %%
#fill the duration with the mean of the column
anime["watched"].replace(np.nan, anime["watched"].mean(), inplace = True)

# %%
anime.isnull().sum()
# Out:
# title                0
# mediaType            0
# eps                  0
# duration             0
# ongoing              0
# startYr              0
# finishYr             0
# sznOfRelease         0
# description       4468
# studios           3208
# tags               313
# contentWarn      10705
# watched              0
# watching             0
# wantWatch            0
# dropped              0
# rating               0
# votes                0
# years_running        0
# dtype: int64

# %%
#we could as well just fill it with a value, lets say "not known" for the remaining missing columns
anime["description"].fillna("not_known", inplace = True)
anime["studios"].fillna("not_known", inplace = True)
anime["tags"].fillna("not_known", inplace = True)
anime["contentWarn"].fillna("not_known", inplace = True)

# %%
anime.isnull().sum()
# Out:
# title            0
# mediaType        0
# eps              0
# duration         0
# ongoing          0
# startYr          0
# finishYr         0
# sznOfRelease     0
# description      0
# studios          0
# tags             0
# contentWarn      0
# watched          0
# watching         0
# wantWatch        0
# dropped          0
# rating           0
# votes            0
# years_running    0
# dtype: int64

# %% [markdown]
# ## Using Covid Data to explain date time

# %%
#get the dates explaing using covid data
covid2 = pd.read_csv(r"C:\Users\User 1\Desktop\Ailead\covid2020.csv")

# %%
covid2.head(2)
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0

# %%
#convert to pandas date time type
covid2["date"] = pd.to_datetime(covid2["date"], format = "%Y-%m-%d")

# %%
covid2.dtypes
# Out:
# date      datetime64[ns]
# county            object
# state             object
# fips             float64
# cases              int64
# deaths           float64
# dtype: object

# %%
#get the year out by creating another columns
covid2["year"] = covid2["date"].dt.year
covid2["month"] = covid2["date"].dt.month
covid2["day"] = covid2["date"].dt.day
